# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Question 1
df = pd.read_csv('tsunami.csv')
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df1 = df[(df['parsed_place'] == 'Japan') & (df['magType'] == 'mb')]
df1
# Out:
#      alert  cdi      code                                             detail  \
# 67     NaN  NaN  1000hbqa  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 713    NaN  NaN  1000hah8  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1124   NaN  NaN  1000h9la  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1309   NaN  NaN  1000h952  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1398   NaN  NaN  1000h8zx  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1422   NaN  1.0  1000h8xg  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1435   NaN  NaN  1000h8vs  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1492   NaN  3.4  1000h8q7  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1563   NaN  NaN  1000h8mj  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1732   NaN  NaN  1000hb41  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1875   NaN  NaN  1000h8c2  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...

# %%
#Question 2
df1['mag'].quantile(0.95)
# Out:
# 4.9

# %%
#Question 3
df2 = df[df['parsed_place']=='Indonesia']
df2
# Out:
#       alert  cdi      code                                             detail  \
# 9       NaN  NaN  1000hbtn  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 13      NaN  NaN  1000hbti  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 180   green  NaN  1000hbhw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 421     NaN  NaN  1000hayw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 660     NaN  NaN  1000haks  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...     ...  ...       ...                                                ...
# 9041    NaN  2.0  2000hhbv  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9075    NaN  NaN  2000hjt8  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9108    NaN  NaN  2000hjt6  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9209    NaN  NaN  2000hg9g  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9212    NaN  3.1  2000hg94  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
# ...

# %%
df2_ts = df2[df2['tsunami']==1]
df2_ts
# Out:
#       alert  cdi      code                                             detail  \
# 1406    NaN  NaN  1000h8zg  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1698    NaN  4.3  1000h8gb  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3112    NaN  NaN  1000h68e  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3150    NaN  NaN  1000h66t  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3605    NaN  NaN  1000h5hb  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3609  green  NaN  1000h5h5  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3692  green  NaN  1000h5el  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3699  green  NaN  1000h5eg  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3707    NaN  NaN  1000h5eb  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3709    NaN  NaN  1000h5e3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3714    NaN  NaN  1000h5du  https://earthquake.usgs.gov/fdsnws/event/1/que...
# ...

# %%
per = round((df2_ts.shape[0]/df2.shape[0])*100, 2)
print('result:',per,'%')
# Out:
# result: 23.13 %

# %%
#Question 4
df3 = df[df['parsed_place']=='Nevada']
df3.describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  681.000000  681.000000  681.000000  6.810000e+02    681.0  681.0
# mean    12.618209    0.151986   10.970631  1.538314e+12      0.0 -480.0
# std      9.866963    0.084662   19.607150  5.965637e+08      0.0    0.0
# ...

# %%
df['ringoffire'] = df['parsed_place'].str.contains('|'.join([
    'Bolivia', 'Chile', 'Ecuador', 'Peru', 'Costa Rica', 
    'Guatemala', '^Mexico', 'Japan', 'Philippines',
    'Indonesia', 'New Zealand', 'Antarctic', 'Canada',
    'Fiji', 'Alaska', 'Washington', 'California', 'Russia', 
    'Taiwan', 'Tonga', 'Kermadec Islands'
]))
df['ringoffire']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9327     True
# 9328     True
# 9329    False
# 9330     True
# 9331     True
# Name: ringoffire, Length: 9332, dtype: bool

# %%
df['ringoffire'].value_counts()
# Out:
# True     7188
# False    2144
# Name: ringoffire, dtype: int64

# %%
num = df[(df['ringoffire']==True)&(df['tsunami']>0)].shape[0]
num
# Out:
# 45
